# %%
# Scaping MyAnimeList ID from Top Anime
# Url : https://myanimelist.net/topanime.php?limit=0

from bs4 import BeautifulSoup

# %%
# Get Anime Url from Sitemap
# Url : https://myanimelist.net/sitemap/anime-001.xml

from bs4 import BeautifulSoup
import json

with open('anime-001.xml', 'r') as f:
    data = f.read()

AnimeData = BeautifulSoup(data, "xml")

url_list = AnimeData.find_all('loc')

listID = []
for url in url_list:
    listID.append(url.string)

with open('anime_url.json', 'w') as json_file:
    json.dump(listID, json_file, indent=4)

# %%
# Get anime detail from anime url

from bs4 import BeautifulSoup
import json
import time
import random
import re

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.firefox.options import Options

options = Options()
options.add_argument('-headless')
driver = webdriver.Firefox(options=options)

with open('anime_url_test.json', 'r') as json_file:
    url_list = json.load(json_file)

failedFile = open('failed.txt', "w")
    
allAnimeData = []
for url in url_list:
    try:
        print("Fetching {}".format(url))
        driver.get(url+"/stats")
        print("Fetch Complete".format(url))
    except:
        failedFile.write(url+"\n")

    try:
        print("Parsing...".format(url))
        content = driver.page_source
        soup = BeautifulSoup(content, 'html.parser')

        title = soup.find('h1', class_='title-name').text
        score = soup.find('span', attrs={'itemprop': 'ratingValue'}).text
        ratingCount = soup.find('span', attrs={'itemprop': 'ratingCount'}).text
        
        rightSide = soup.find('div', class_='rightside')
        stats = rightSide.find_all("div", class_="spaceit_pad", recursive=False)

        pattern = r'[\d,]+'
        summary_stats = []
        for stat in stats:
            numbers = re.findall(pattern, stat.text)
            summary_stats.append(numbers[0])
        cleaned_summary = [num.replace(',', '') for num in summary_stats]

        anime = {
            'title': title,
            'score': score,
            'rating_count': ratingCount,
            'watching': cleaned_summary[0],
            'complete': cleaned_summary[1],
            'on_hold': cleaned_summary[2],
            'dropped': cleaned_summary[3],
            'plan_to_watch': cleaned_summary[4],
            'total': cleaned_summary[5],
        }

        allAnimeData.append(anime)

        print("Parsing Complete")
        random_sleep_time = random.uniform(1, 2)
        print(f"Sleeping for {random_sleep_time:.2f} seconds...")
        time.sleep(random_sleep_time)
    except Exception as error:
        failedFile.write(url+"\n")
        print(error)
        continue

with open('anime_data.json', 'w') as json_file:
    json.dump(allAnimeData, json_file, indent=4)
    
json_file.close()
failedFile.close()
# Out:
# Fetching https://myanimelist.net/anime/1/Cowboy_Bebop
# Fetch Complete
# Parsing...
# module 're' has no attribute 'find'

# %%
# Crawling using JIKAN API

import requests

with open('anime_url.json', 'r') as json_file:
    url_list = json.load(json_file)

dataFull = []

counter = 0

id_pattern = re.compile(r'/anime/(\d+)/')
for url in url_list:
    match = id_pattern.search(url)
    if match:
        anime_id = match.group(1)  # Extract the ID part

    jikanUrl = "https://api.jikan.moe/v4/anime/{}/full".format(anime_id)

    print("Fetching data {}".format(url))
    animeData = requests.get(url = jikanUrl)

    data = animeData.json()

    dataFull.append(data['data'])

    counter = counter + 1

    time.sleep(2)

with open('anime_data.json', 'w') as json_file:
    json.dump(dataFull, json_file, indent=4)
# Out:
# Fetching data https://myanimelist.net/anime/1/Cowboy_Bebop
# Fetching data https://myanimelist.net/anime/5/Cowboy_Bebop__Tengoku_no_Tobira
# Fetching data https://myanimelist.net/anime/6/Trigun
# Fetching data https://myanimelist.net/anime/7/Witch_Hunter_Robin
# Fetching data https://myanimelist.net/anime/8/Bouken_Ou_Beet
# Fetching data https://myanimelist.net/anime/15/Eyeshield_21
# Fetching data https://myanimelist.net/anime/16/Hachimitsu_to_Clover
# Fetching data https://myanimelist.net/anime/77/Mahou_Shoujo_Lyrical_Nanoha_As
# Fetching data https://myanimelist.net/anime/79/Shuffle
# Fetching data https://myanimelist.net/anime/80/Kidou_Senshi_Gundam
# Fetching data https://myanimelist.net/anime/81/Kidou_Senshi_Gundam__Dai_08_MS_Shoutai
# Fetching data https://myanimelist.net/anime/82/Kidou_Senshi_Gundam_0080__Pocket_no_Naka_no_Sensou
# Fetching data https://myanimelist.net/anime/83/Kidou_Senshi_Gundam__Dai_08_MS_Shoutai_-_Millers_Report
# Fetching data https://myanimelist.net/anime/84/Kidou_Senshi_Gundam_0083__Stardust_Memory
# Fetching data https://myanimelist.net/anime/85/Kidou_Senshi_Zeta_Gundam
# Fetching data https://myanimelist.net/anime/86/Kidou_Senshi_Gundam_ZZ
# Fetching data https://myanimelist.net/anime/87/Kidou_Senshi_Gundam__Gyakushuu_no_Char
# Fetching data https://myanimelist.net/anime/88/Kidou_Senshi_Gundam_F91
# Fetching data https://myanimelist.net/anime/89/Kidou_Senshi_Victory_Gundam
# Fetching data https://myanimelist.net/anime/90/Shin_Kidou_Senki_Gundam_Wing
# Fetching data https://myanimelist.net/anime/91/Shin_Kidou_Senki_Gundam_Wing__Endless_Waltz
# Fetching data https://myanimelist.net/anime/92/Kidou_Shinseiki_Gundam_X
# Fetching data https://myanimelist.net/anime/93/Kidou_Senshi_Gundam_SEED
# Fetching data https://myanimelist.net/anime/94/Kidou_Senshi_Gundam_SEED_Destiny
# Fetching data https://myanimelist.net/anime/95/Turn_A_Gundam
# Fetching data https://myanimelist.net/anime/96/Kidou_Butouden_G_Gundam
# Fetching data https://myanimelist.net/anime/97/Last_Exile
# Fetching data https://myanimelist.net/anime/98/Mai-HiME
# Fetching data https://myanimelist.net/anime/99/Mai-Otome
# Fetching data https://myanimelist.net/anime/100/Shin_Shirayuki-hime_Densetsu_Prétear
# Fetching data https://myanimelist.net/anime/101/Air
# Fetching data https://myanimelist.net/anime/102/Aishiteruze_Baby★★
# Fetching data https://myanimelist.net/anime/103/Akazukin_Chacha
# Fetching data https://myanimelist.net/anime/104/Ayashi_no_Ceres
# Fetching data https://myanimelist.net/anime/105/Boys_Be
# Fetching data https://myanimelist.net/anime/106/Hana_yori_Dango
# Fetching data https://myanimelist.net/anime/107/Ou_Dorobou_Jing
# Fetching data https://myanimelist.net/anime/108/Ou_Dorobou_Jing_in_Seventh_Heaven
# Fetching data https://myanimelist.net/anime/109/Bakuretsu_Tenshi
# Fetching data https://myanimelist.net/anime/110/Chuuka_Ichiban
# Fetching data https://myanimelist.net/anime/111/Corrector_Yui
# Fetching data https://myanimelist.net/anime/112/Chou_Henshin_Cosprayers
# Fetching data https://myanimelist.net/anime/113/Uchuu_no_Stellvia
# Fetching data https://myanimelist.net/anime/114/Sakigake_Cromartie_Koukou
# Fetching data https://myanimelist.net/anime/115/Ijigen_no_Sekai_El-Hazard
# Fetching data https://myanimelist.net/anime/116/Shinpi_no_Sekai_El-Hazard_TV
# Fetching data https://myanimelist.net/anime/117/Shinpi_no_Sekai_El-Hazard
# Fetching data https://myanimelist.net/anime/118/Shinpi_no_Sekai_El-Hazard_Season_2
# Fetching data https://myanimelist.net/anime/119/Final_Approach
# Fetching data https://myanimelist.net/anime/120/Fruits_Basket
# Fetching data https://myanimelist.net/anime/121/Fullmetal_Alchemist
